# %%
# !pip3 install qiskit
# Out:
# Collecting qiskit
#   Using cached qiskit-2.5.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting numpy<3,>=2.0 (from qiskit)
#   Using cached numpy-2.5.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting scipy>=1.14 (from qiskit)
#   Using cached scipy-1.18.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Using cached rustworkx-0.18.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting dill>=0.3 (from qiskit)
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Using cached stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /Users/hs02/Desktop/Quantum Stuff/.venv/lib/python3.14/site-packages (from qiskit) (4.16.0)
# Using cached qiskit-2.5.0-cp310-abi3-macosx_11_0_arm64.whl (8.8 MB)
# Using cached numpy-2.5.1-cp314-cp314-macosx_14_0_arm64.whl (5.3 MB)
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached rustworkx-0.18.0-cp310-abi3-macosx_11_0_arm64.whl (2.1 MB)
# Using cached scipy-1.18.0-cp314-cp314-macosx_14_0_arm64.whl (20.4 MB)
# Using cached stevedore-5.9.0-py3-none-any.whl (54 kB)
# Installing collected packages: stevedore, numpy, dill, scipy, rustworkx, qiskit
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [qiskit]2m5/6 [qiskit]
# Successfully installed dill-0.4.1 numpy-2.5.1 qiskit-2.5.0 rustworkx-0.18.0 scipy-1.18.0 stevedore-5.9.0

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.measure(qreg_q[0], creg_c[0])
print(circuit)
# Out:
#      ┌───┐┌─┐
# q_0: ┤ H ├┤M├
#      └───┘└╥┘
# q_1: ──────╫─
#            ║
# q_2: ──────╫─
#            ║
# q_3: ──────╫─
#            ║
# c: 4/══════╩═
#            0
